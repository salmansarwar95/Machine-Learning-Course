# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("family.csv")
print (df)

plt.figure(figsize=(7,5))
sns.barplot(x="Name", y="Age", data=df)
# Out:
#        Name  Age
# 0    Salman   22
# 1      Sana   20
# 2      Asad   17
# 3      Saba   22
# 4     Rabia   18
# 5   Tayyeba   16
# 6   Zeeshan   18
# 7  Abdullah   16
# 8     Anisa   21
# <Axes: xlabel='Name', ylabel='Age'>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("family.csv")
print(df)

plt.figure(figsize=(5,5))
sns.barplot(x="Name", y="Age", data=df)
plt.title("Age Distribution by Name")
plt.show()
# Out:
#        Name  Age
# 0    Salman   22
# 1      Sana   20
# 2      Asad   17
# 3      Saba   22
# 4     Rabia   18
# 5   Tayyeba   16
# 6   Zeeshan   18
# 7  Abdullah   16
# 8     Anisa   21

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("family.csv")
print(df)

plt.figure(figsize=(5,5))
sns.barplot(x="Name", y="Age", data=df)  # <-- Make sure "Age" is correct here
plt.title("Age Distribution by Name")
plt.show()
# Out:
#        Name  Age
# 0    Salman   22
# 1      Sana   20
# 2      Asad   17
# 3      Saba   22
# 4     Rabia   18
# 5   Tayyeba   16
# 6   Zeeshan   18
# 7  Abdullah   16
# 8     Anisa   21

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("family.csv")
df.columns = df.columns.str.strip()  # Fix column names
print(df)
print(df.dtypes)
plt.figure(figsize=(5, 5))
plt.bar("Name", "Age", data=df)
plt.title("Family Age Chart")
plt.show()
# Out:
#        Name  Age
# 0    Salman   22
# 1      Sana   20
# 2      Asad   17
# 3      Saba   22
# 4     Rabia   18
# 5   Tayyeba   16
# 6   Zeeshan   18
# 7  Abdullah   16
# 8     Anisa   21
# Name    object
# Age      int64
# dtype: object
