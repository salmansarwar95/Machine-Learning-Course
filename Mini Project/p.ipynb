# %%
import numpy as np
df = np.array([1,2])
print(df)
# Out:
# [1 2]

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
ss = pd.read_csv("family.csv")
print (ss)
print(ss.dtypes)
# Out:
#        Name  Age
# 0    Salman   22
# 1      Sana   20
# 2      Asad   17
# 3      Saba   22
# 4     Rabia   18
# 5   Tayyeba   16
# 6   Zeeshan   18
# 7  Abdullah   16
# 8     Anisa   21
# Name    object
# Age      int64
# dtype: object

# %%
n_age = ss["Age"]
print(n_age)
# Out:
# 0    22
# 1    20
# 2    17
# 3    22
# 4    18
# 5    16
# 6    18
# 7    16
# 8    21
# Name: Age, dtype: int64

# %%
avg = np.average(n_age)
print (avg)
# Out:
# 18.88888888888889

# %%
print (ss)
# Out:
#        Name  Age
# 0    Salman   22
# 1      Sana   20
# 2      Asad   17
# 3      Saba   22
# 4     Rabia   18
# 5   Tayyeba   16
# 6   Zeeshan   18
# 7  Abdullah   16
# 8     Anisa   21

# %%
plt.figure(figsize=(10,5))
sns.barplot(x = 'Name', y = "Age", data = ss)
# Out:
# <Axes: xlabel='Name', ylabel='Age'>
