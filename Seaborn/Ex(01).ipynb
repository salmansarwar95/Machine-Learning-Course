# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# data = pd.read_csv("tips.csv") # through pandas
data = sns.load_dataset("tips") # through seaborn
ss = (data.head(10))
print(ss)
# print(ss.sum())

# Load sample dataset
df = sns.load_dataset("tips")

# Line plot of total_bill vs tip
plt.figure(figsize=(5,5))
sns.lineplot(x = "total_bill", y="size", color = "red", data=ss, marker="o")
plt.title("Total Bill compared to Size")
plt.xlabel("Total Bill")
plt.ylabel("Size")
plt.grid(True)
plt.get_current_fig_manager
plt.tight_layout()
plt.show()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %%
import seaborn as sns
import matplotlib.pyplot as plt

df = sns.load_dataset("tips")

# Show correlation heatmap (only numeric columns)
correlation = df.corr(numeric_only=True)
sns.heatmap(correlation, annot=True, cmap="coolwarm")
plt.title("Correlation Between Columns")
plt.show()
