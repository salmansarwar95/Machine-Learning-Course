# %% [markdown]
# ### Creation of Series

# %%
import pandas as pd

# %%
import pandas as pd

s = pd.Series([1, 2, 3])
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
s = pd.Series([10, 20, 30, 40, 50, 60, 70], index = ["a", "b", "c", "d", "e", "f", "g"])
print (s)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# g    70
# dtype: int64

# %%
import pandas as pd
#series form custom indexing
s = pd.Series([10, 20, 30, 40, 50, 60, 70], index=["a", "b", "c", "d", "e", "f", "g"])
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# e    50
# f    60
# g    70
# dtype: int64

# %%
import pandas as pd
s = pd.Series([11, 22, 33])
print(s)
# Out:
# 0    11
# 1    22
# 2    33
# dtype: int64

# %%
import pandas as pd
Data = {"Math":98, "English":90, "Urdu":99} #series from dictrionary type indexing
Marks = pd.Series(Data)
print(Marks)
# Out:
# Math       98
# English    90
# Urdu       99
# dtype: int64

# %%
import pandas as pd

# %%
dataset = pd.Series([1, 2, 3, 4], index=["a", "b", "c", "d"])
print(dataset)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
dicc = {1 : "Salman", 2 : "Zeeshan", 3 : "Asad", 4 : "Abdullah"}
dic = pd.Series(dicc)
dic.isnull
# Out:
# <bound method Series.isnull of 1      Salman
# 2     Zeeshan
# 3        Asad
# 4    Abdullah
# dtype: object>
