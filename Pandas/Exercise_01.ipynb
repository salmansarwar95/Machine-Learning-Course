# %% [markdown]
# ### Exercise

# %%
import pandas as pd

# %%
Scores =pd.Series([88, 92, 79, 93, 85] ,index=["Alice", "Bob", "Charlie", "David", "Eva"])
print(Scores)
# Out:
# Alice      88
# Bob        92
# Charlie    79
# David      93
# Eva        85
# dtype: int64

# %%
print("Bos's Score:", Scores["Bob"])
# Out:
# Bos's Score: 92

# %%
print("Students that have marks above then 85:")
print(Scores[Scores>85])
# Out:
# Students that have marks above then 85:
# Alice    88
# Bob      92
# David    93
# dtype: int64

# %%
print("Before bounes score:")
print(Scores)
bounes_score = Scores + 5
print("\nAfter Bounes Score: ")
print(bounes_score)
# Out:
# Before bounes score:
# Alice      88
# Bob        92
# Charlie    79
# David      93
# Eva        85
# dtype: int64
#
# After Bounes Score:
# Alice      93
# Bob        97
# Charlie    84
# David      98
# Eva        90
# dtype: int64

# %%
print("Is Eva exists?:")
print("Eva" in Scores)
# Out:
# Is Eva exists?:
# True
