# %%
import pandas as pd

# %%
df = pd.DataFrame({"Name" : ["Cat", "Dog", "Cow", "Fog", "Mosqito", "Fish", "Parrot", "Crow"]})
print(df)
# Out:
#       Name
# 0      Cat
# 1      Dog
# 2      Cow
# 3      Fog
# 4  Mosqito
# 5     Fish
# 6   Parrot
# 7     Crow

# %%
from sklearn.preprocessing import LabelEncoder

# %%
la = LabelEncoder()
df["en_name"] = la.fit_transform(df["Name"])

# %%
print(df)
# Out:
#       Name  en_name
# 0      Cat        0
# 1      Dog        3
# 2      Cow        1
# 3      Fog        5
# 4  Mosqito        6
# 5     Fish        4
# 6   Parrot        7
# 7     Crow        2
